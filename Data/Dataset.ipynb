# %%
pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 2.4 MB/s  0:00:04 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 2.5 MB/s  0:00:02 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
phones = [
    "iphone 11",
    "iphone 12",
    "iphone 13",
    "iphone 14",
    "iphone 15",
    "iphone 16",

    "samsung s21",
    "samsung s22",
    "samsung s23",
    "samsung s24",
    "samsung s25",

    "oneplus 9",
    "oneplus 10",
    "oneplus 11",
    "oneplus 12",
    "oneplus 13",

    "google pixel 6",
    "google pixel 7",
    "google pixel 8",
    "google pixel 9",

    "nothing phone 1",
    "nothing phone 2",
    "nothing phone 3",

    "motorola edge 40",
    "motorola edge 50",

    "xiaomi 13",
    "xiaomi 14",
    "redmi note 13",
    "redmi note 14",
    "realme gt 6"
]
laptops = [
    "macbook air m1",
    "macbook air m2",
    "macbook air m3",

    "macbook pro m1",
    "macbook pro m2",
    "macbook pro m3",

    "dell xps 13",
    "dell xps 15",

    "hp pavilion 14",
    "hp pavilion 15",

    "hp omen 16",

    "lenovo ideapad",
    "lenovo legion 5",
    "lenovo legion 7",

    "asus rog strix",
    "asus rog zephyrus",
    "asus tuf gaming",

    "acer nitro 5",
    "acer predator",

    "msi katana",
    "msi stealth",

    "samsung galaxy book",

    "surface laptop 5",
    "surface laptop 6"
]
earbuds = [
    "airpods 2",
    "airpods 3",
    "airpods pro",
    "airpods pro 2",

    "galaxy buds 2",
    "galaxy buds 2 pro",
    "galaxy buds 3",

    "sony wf 1000xm5",
    "sony wf 1000xm4",

    "jbl tune buds",
    "jbl live buds",

    "boat airdopes 141",
    "boat airdopes 181",

    "oneplus buds pro",
    "oneplus buds 3",

    "nothing ear 1",
    "nothing ear 2",

    "bose quietcomfort earbuds"
]
tvs = [
    "samsung qled tv",
    "samsung oled tv",

    "lg oled tv",
    "lg qned tv",

    "sony bravia 55 inch",
    "sony bravia 65 inch",

    "xiaomi smart tv",
    "redmi smart tv",

    "oneplus smart tv",

    "hisense smart tv",

    "tcl qled tv",

    "vu smart tv"
]
cameras = [
    "canon eos r10",
    "canon eos r50",
    "canon eos r6",

    "nikon z50",
    "nikon z6",

    "sony a6400",
    "sony a6700",
    "sony a7iii",
    "sony a7iv",

    "fujifilm xt30",
    "fujifilm xt5",

    "gopro hero 11",
    "gopro hero 12",

    "insta360 x3",
    "insta360 x4"
]
mice = [
    "logitech g102",
    "logitech g304",
    "logitech g502",
    "logitech mx master 3",

    "razer deathadder",
    "razer basilisk",

    "steelseries rival 3",

    "corsair harpoon",
    "corsair dark core",

    "hp wireless mouse",
    "dell wireless mouse",

    "lenovo wireless mouse",

    "apple magic mouse",

    "asus rog mouse",

    "redragon gaming mouse"
]
keyboards = [
    "logitech g213",
    "logitech g413",

    "keychron k2",
    "keychron k6",
    "keychron k8",

    "razer blackwidow",
    "razer huntsman",

    "corsair k55",
    "corsair k70",

    "steelseries apex 3",
    "steelseries apex 5",

    "redragon k552",

    "hp mechanical keyboard",

    "dell mechanical keyboard",

    "apple magic keyboard",

    "asus rog keyboard"
]
watches = [
    "apple watch se",
    "apple watch series 9",
    "apple watch ultra",

    "samsung galaxy watch 5",
    "samsung galaxy watch 6",
    "samsung galaxy watch 7",

    "oneplus watch 2",

    "pixel watch 2",
    "pixel watch 3",

    "amazfit gtr 4",
    "amazfit gts 4",

    "noise colorfit",
    "noise halo",

    "boat wave call",

    "fire boltt ninja"
]
speakers = [
    "jbl flip 6",
    "jbl charge 5",

    "sony srs xb13",
    "sony srs xb23",

    "boat stone 350",
    "boat stone 650",

    "bose soundlink flex",

    "marshall emberton",

    "ultimate ears boom 3",

    "amazon echo dot",
    "amazon echo",

    "google nest mini",

    "harman kardon onyx"
]
chargers = [
    "iphone charger",
    "iphone fast charger",

    "samsung charger",
    "samsung 25w charger",
    "samsung 45w charger",

    "oneplus supervooc charger",

    "macbook charger",

    "usb c charger",

    "wireless charger",

    "anker charger",

    "belkin charger",

    "power delivery charger",

    "car charger",

    "gan charger"
]
powerbanks = [
    "mi power bank",
    "anker power bank",

    "boat power bank",

    "ambrane power bank",

    "10000mah power bank",

    "20000mah power bank",

    "wireless power bank",

    "fast charging power bank"
]
monitors = [
    "lg ultragear monitor",

    "samsung odyssey monitor",

    "dell ultrasharp monitor",

    "asus rog monitor",

    "benq monitor",

    "acer nitro monitor",

    "144hz gaming monitor",

    "240hz gaming monitor",

    "4k monitor",

    "ultrawide monitor"
]
storage = [
    "samsung ssd",

    "crucial ssd",

    "wd external hard drive",

    "seagate external hard drive",

    "1tb ssd",

    "2tb ssd",

    "usb flash drive",

    "memory card"
]
phone_accessories = [
    "apple magsafe charger",
    "apple magsafe battery pack",
    "apple silicone case",
    "apple clear case",

    "samsung wireless charger",
    "samsung smart tag",
    "samsung silicone case",
    "samsung leather case",

    "oneplus sandstone case",
    "oneplus wireless charger",

    "spigen rugged armor case",
    "spigen screen protector",

    "esr magsafe charger",
    "esr clear case",

    "anker wireless charger",
    "anker power bank",

    "belkin magsafe charger",

    "tempered glass screen protector",
    "privacy screen protector",

    "usb c cable",
    "lightning cable",

    "phone tripod",
    "phone gimbal",

    "car phone mount",

    "selfie stick",

    "phone ring holder"
]
fridges = [
    "lg 260l refrigerator",
    "lg 360l refrigerator",
    "lg side by side refrigerator",

    "samsung 253l refrigerator",
    "samsung 345l refrigerator",
    "samsung family hub refrigerator",

    "whirlpool 265l refrigerator",
    "whirlpool 340l refrigerator",

    "haier 190l refrigerator",
    "haier 320l refrigerator",

    "godrej 180l refrigerator",
    "godrej 244l refrigerator",

    "panasonic inverter refrigerator",

    "bosch double door refrigerator"
]
washing_machines = [
    "lg front load washing machine",
    "lg top load washing machine",

    "samsung front load washing machine",
    "samsung top load washing machine",

    "whirlpool semi automatic washing machine",
    "whirlpool front load washing machine",

    "bosch 7kg washing machine",
    "bosch 8kg washing machine",

    "ifb front load washing machine",

    "haier top load washing machine",

    "panasonic washing machine",

    "godrej washing machine"
]
acs = [
    "lg 1 ton ac",
    "lg 1.5 ton ac",
    "lg dual inverter ac",

    "samsung 1 ton ac",
    "samsung 1.5 ton ac",

    "daikin 1 ton ac",
    "daikin 1.5 ton ac",
    "daikin inverter ac",

    "voltas 1 ton ac",
    "voltas 1.5 ton ac",

    "blue star 1 ton ac",
    "blue star 1.5 ton ac",

    "hitachi inverter ac",

    "carrier split ac",

    "panasonic smart ac"
]
microwaves = [
    "lg convection microwave",
    "lg solo microwave",

    "samsung convection microwave",
    "samsung grill microwave",

    "ifb convection microwave",

    "whirlpool microwave oven",

    "haier microwave oven",

    "panasonic microwave oven",

    "godrej microwave oven",

    "bosch microwave oven"
]
dishwashers = [
    "bosch dishwasher",
    "bosch series 4 dishwasher",
    "bosch series 6 dishwasher",

    "ifb dishwasher",

    "lg dishwasher",

    "samsung dishwasher",

    "siemens dishwasher",

    "voltas beko dishwasher",

    "hafele dishwasher",

    "faber dishwasher"
]
colors = [
    "black",
    "white",
    "silver",
    "gold",
    "blue",
    "red",
    "green",
    "gray",
    "pink"
]
sizes = [
    "small",
    "medium",
    "large",
    "extra large"
]
furniture = [

    # Sofa
    "l shape sofa",
    "sectional sofa",
    "recliner sofa",
    "fabric sofa",
    "leather sofa",
    "wooden sofa",
    "3 seater sofa",
    "5 seater sofa",
    "corner sofa",
    "sofa cum bed",

    # Chair
    "office chair",
    "ergonomic chair",
    "gaming chair",
    "study chair",
    "wooden chair",
    "plastic chair",
    "folding chair",
    "recliner chair",
    "dining chair",
    "rocking chair",

    # Table
    "study table",
    "computer table",
    "office desk",
    "dining table",
    "coffee table",
    "bedside table",
    "wooden table",
    "folding table",
    "conference table",
    "workstation desk",

    # Bed
    "king size bed",
    "queen size bed",
    "single bed",
    "double bed",
    "bunk bed",
    "wooden bed",
    "storage bed",
    "hydraulic bed",
    "metal bed",
    "sofa bed",

    # Bedsheets
    "cotton bedsheet",
    "king size bedsheet",
    "queen size bedsheet",
    "printed bedsheet",
    "double bedsheet",
    "single bedsheet",
    "luxury bedsheet",
    "microfiber bedsheet",

    # Wardrobe / Cupboard
    "2 door wardrobe",
    "3 door wardrobe",
    "4 door wardrobe",
    "sliding wardrobe",
    "wooden wardrobe",
    "steel cupboard",
    "storage cupboard",
    "office cupboard",

    # Doors
    "wooden door",
    "main door",
    "sliding door",
    "steel door",
    "glass door",
    "bathroom door",
    "interior door",

    # Locks
    "smart lock",
    "digital lock",
    "door lock",
    "fingerprint lock",
    "padlock",
    "godrej lock",
    "electronic lock",

    # Dustbins
    "kitchen dustbin",
    "smart dustbin",
    "plastic dustbin",
    "steel dustbin",
    "automatic dustbin",
    "pedal dustbin",

    # Bags
    "laptop bag",
    "travel backpack",
    "school bag",
    "office bag",
    "duffle bag",
    "trolley bag",
    "gym bag",
    "messenger bag",

    # Shelves
    "bookshelf",
    "wall shelf",
    "storage shelf",
    "corner shelf",
    "wooden shelf",

    # TV Units
    "tv unit",
    "wall mounted tv unit",
    "wooden tv unit",

    # Shoe Storage
    "shoe rack",
    "shoe cabinet",

    # Mirrors
    "dressing mirror",
    "full length mirror",
    "wall mirror"
]
kitchen_appliances = [

    # Mixer Grinder
    "prestige mixer grinder",
    "sujata mixer grinder",
    "philips mixer grinder",
    "bajaj mixer grinder",
    "butterfly mixer grinder",
    "havells mixer grinder",

    # Air Fryer
    "philips air fryer",
    "instant air fryer",
    "havells air fryer",
    "prestige air fryer",
    "pigeon air fryer",

    # Induction Cooktop
    "philips induction cooktop",
    "prestige induction cooktop",
    "pigeon induction cooktop",
    "bajaj induction cooktop",
    "havells induction cooktop",

    # Gas Stove
    "prestige gas stove",
    "sunflame gas stove",
    "glass top gas stove",
    "4 burner gas stove",
    "3 burner gas stove",
    "2 burner gas stove",

    # Chimney
    "faber chimney",
    "elica chimney",
    "hindware chimney",
    "bosch chimney",
    "kitchen chimney",

    # Electric Kettle
    "philips electric kettle",
    "havells electric kettle",
    "prestige electric kettle",
    "pigeon electric kettle",
    "butterfly electric kettle",

    # Coffee Machine
    "nespresso coffee machine",
    "philips coffee machine",
    "delonghi coffee machine",
    "agaro coffee machine",
    "espresso machine",

    # Juicer
    "philips juicer",
    "sujata juicer",
    "bajaj juicer",
    "havells juicer",
    "cold press juicer",

    # Toaster
    "philips toaster",
    "morphy richards toaster",
    "havells toaster",
    "prestige toaster",
    "2 slice toaster",
    "4 slice toaster",

    # Rice Cooker
    "prestige rice cooker",
    "panasonic rice cooker",
    "philips rice cooker",
    "pigeon rice cooker",
    "electric rice cooker",

    # OTG
    "bajaj otg",
    "agaro otg",
    "philips otg",
    "morphy richards otg",
    "oven toaster griller",

    # Food Processor
    "philips food processor",
    "inalsa food processor",
    "bajaj food processor",
    "havells food processor",

    # Water Purifier
    "kent water purifier",
    "aquaguard water purifier",
    "livpure water purifier",
    "ro water purifier",
    "uv water purifier",

    # Dishwasher Accessories
    "dishwasher tablets",
    "dishwasher detergent",
    "dishwasher rinse aid",

    # Vacuum Cleaner
    "dyson vacuum cleaner",
    "philips vacuum cleaner",
    "eureka forbes vacuum cleaner",
    "robot vacuum cleaner",
    "wet and dry vacuum cleaner",

    # Water Dispenser
    "hot and cold water dispenser",
    "voltas water dispenser",
    "blue star water dispenser",

    # Blender
    "nutribullet blender",
    "philips blender",
    "portable blender",
    "smoothie blender"
]
fitness_equipment = [

    # Treadmills
    "powermax treadmill",
    "fitkit treadmill",
    "lifelong treadmill",
    "cultsport treadmill",
    "motorized treadmill",
    "foldable treadmill",

    # Exercise Bikes
    "spin bike",
    "exercise bike",
    "air bike",
    "cultsport exercise bike",
    "fitkit exercise bike",

    # Dumbbells
    "5kg dumbbell",
    "10kg dumbbell",
    "20kg dumbbell",
    "adjustable dumbbell",
    "hex dumbbell",
    "rubber dumbbell",

    # Barbells
    "olympic barbell",
    "curl barbell",
    "barbell rod",
    "barbell weight set",

    # Weight Plates
    "5kg weight plate",
    "10kg weight plate",
    "20kg weight plate",
    "bumper plate",
    "rubber weight plate",

    # Benches
    "adjustable bench",
    "weight bench",
    "incline bench",
    "flat bench",

    # Home Gym
    "multi gym machine",
    "home gym machine",
    "smith machine",
    "functional trainer",

    # Resistance Bands
    "resistance band",
    "loop resistance band",
    "pull up resistance band",

    # Yoga
    "yoga mat",
    "anti slip yoga mat",
    "cork yoga mat",
    "yoga block",
    "yoga wheel",

    # Pull Up Equipment
    "pull up bar",
    "doorway pull up bar",
    "wall mounted pull up bar",

    # Kettlebells
    "8kg kettlebell",
    "12kg kettlebell",
    "16kg kettlebell",
    "adjustable kettlebell",

    # Jump Rope
    "speed jump rope",
    "weighted jump rope",
    "digital jump rope",

    # Rowing Machines
    "rowing machine",
    "water rowing machine",
    "magnetic rowing machine",

    # Ellipticals
    "elliptical trainer",
    "cross trainer",
    "elliptical machine",

    # Massage Recovery
    "massage gun",
    "deep tissue massage gun",
    "foam roller",

    # Fitness Tracking
    "fitness tracker",
    "heart rate monitor",
    "smart fitness band",

    # Punching Equipment
    "punching bag",
    "boxing gloves",
    "boxing training kit",

    # Core Equipment
    "ab roller",
    "ab crunch machine",
    "sit up bench",

    # Mobility
    "stretching strap",
    "mobility band",
    "balance board"
]
automotive_accessories = [

    # Seat Covers
    "car seat cover",
    "leather seat cover",
    "waterproof seat cover",
    "premium seat cover",
    "rear seat cover",

    # Dash Cameras
    "70mai dash cam",
    "ddpai dash cam",
    "redtiger dash cam",
    "4k dash cam",
    "dual channel dash cam",

    # Phone Holders
    "car phone holder",
    "magnetic phone holder",
    "dashboard phone holder",
    "air vent phone holder",

    # Car Chargers
    "usb car charger",
    "fast car charger",
    "dual port car charger",
    "wireless car charger",

    # Vacuum Cleaners
    "car vacuum cleaner",
    "wireless car vacuum",
    "portable vacuum cleaner",

    # Perfumes
    "car perfume",
    "car air freshener",
    "gel air freshener",
    "hanging car perfume",

    # Steering Covers
    "steering wheel cover",
    "leather steering cover",
    "sports steering cover",

    # Floor Mats
    "car floor mat",
    "7d floor mat",
    "3d floor mat",
    "rubber floor mat",

    # Sunshades
    "car sunshade",
    "windshield sunshade",
    "rear window sunshade",

    # Tyre Accessories
    "tyre inflator",
    "portable tyre inflator",
    "digital tyre inflator",
    "tyre pressure gauge",

    # Cleaning
    "car cleaning kit",
    "microfiber cleaning cloth",
    "car wash shampoo",
    "car polish",

    # Security
    "gps tracker",
    "car anti theft device",
    "steering lock",

    # Lighting
    "led headlight",
    "fog lamp",
    "car interior lights",

    # Audio
    "car stereo",
    "android car stereo",
    "subwoofer",
    "car amplifier",

    # Navigation
    "android auto display",
    "apple carplay display",
    "car navigation system",

    # Storage
    "car trunk organizer",
    "seat back organizer",
    "car storage box",

    # Emergency
    "car emergency kit",
    "jumper cable",
    "jump starter",
    "tow rope",

    # Cameras
    "reverse parking camera",
    "360 parking camera",

    # Covers
    "car cover",
    "waterproof car cover",
    "dustproof car cover",

    # Accessories
    "armrest cushion",
    "gear knob cover",
    "car cup holder",
    "car tissue box"
]
templates = [
    "price of {}",
    "{} with return offer",
    "{} with return",


    "best {}",
    "cheap {}",
    "premium {}",

    "latest {}",
    "new {}",
    "newest {}",

    "top rated {}",
    "most popular {}",

    "buy {}",
    "{} online",
    "{} near me",

    "{} review",
    "{} reviews",

    "{} price",
    "{} price in india",

    "{} under 100",
    "{} under 500",
    "{} under 1000",
    "{} under 5000",
    "{} under 10000",
    "{} under 50000",
    "{} under 100000",

    "10% discount on {}",
    "20% discount on {}",
    "30% discount on {}",
    "40% discount on {}",
    "50% discount on {}",

    "{} for students",
    "{} for office",
    "{} for home",
    "{} for professionals",

    "{} with warranty",
    "{} with guarantee",

    "{} with discount",
    "{} on sale",

    "{} with accessories",
    "{} with all accessories",

    "{} comparison",

    "{} maintenance",
    "{} replacement",

    "{} latest model",
    "{} old model",

    "{} newly launched",
    "{} 2023",
    "{} 2024",
    "{} 2025",
    "{} 2026"
]
pet_supplies = [

    # Dog Food
    "pedigree dog food",
    "drools dog food",
    "royal canin dog food",
    "grain free dog food",
    "puppy dog food",

    # Cat Food
    "whiskas cat food",
    "royal canin cat food",
    "persian cat food",
    "kitten cat food",
    "dry cat food",

    # Pet Beds
    "dog bed",
    "cat bed",
    "orthopedic dog bed",
    "washable pet bed",

    # Pet Carriers
    "pet carrier",
    "cat carrier",
    "dog travel carrier",
    "pet backpack carrier",

    # Leashes
    "dog leash",
    "retractable leash",
    "training leash",
    "dog harness",

    # Grooming
    "pet shampoo",
    "dog shampoo",
    "cat shampoo",
    "pet grooming kit",
    "pet trimmer",

    # Toys
    "dog chew toy",
    "dog rope toy",
    "cat toy",
    "interactive cat toy",
    "pet ball",

    # Feeding
    "pet bowl",
    "automatic pet feeder",
    "water dispenser for pets",
    "slow feeder bowl",

    # Health
    "tick collar",
    "flea treatment",
    "dog multivitamin",
    "pet supplements",

    # Litter
    "cat litter",
    "cat litter box",
    "automatic litter box",

    # Training
    "dog training pads",
    "dog clicker",
    "training treats",

    # Accessories
    "pet clothes",
    "dog jacket",
    "pet raincoat",
    "pet sunglasses",

    # Safety
    "pet gps tracker",
    "pet seat belt",
    "pet safety gate",

    # Cleaning
    "pet hair remover",
    "pet stain remover",
    "lint roller for pet hair"
]
beauty_personal_care = [

    "philips trimmer",
    "mi trimmer",
    "beard trimmer",

    "hair dryer",
    "philips hair dryer",
    "havells hair dryer",

    "hair straightener",
    "hair curler",

    "electric toothbrush",
    "oral b toothbrush",

    "face wash",
    "vitamin c serum",
    "moisturizer",

    "sunscreen",
    "spf 50 sunscreen",

    "face scrub",
    "face mask",

    "body lotion",
    "body wash",

    "perfume",
    "deodorant",

    "makeup kit",
    "foundation",
    "lipstick",

    "facial kit",
    "beauty kit",

    "epilator",
    "women trimmer",

    "massage gun",
    "facial massager"
]
motorcycle_accessories = [

    "full face helmet",
    "modular helmet",
    "vega helmet",
    "steelbird helmet",
    "axor helmet",

    "riding gloves",
    "waterproof riding gloves",

    "riding jacket",
    "mesh riding jacket",

    "bike cover",
    "waterproof bike cover",

    "motorcycle phone mount",

    "motorcycle saddle bag",
    "tank bag",

    "bike crash guard",
    "engine guard",

    "motorcycle fog lights",

    "bike tyre inflator",

    "motorcycle gps tracker",

    "bike chain cleaner",
    "chain lubricant",

    "motorcycle action camera mount",

    "riding boots",

    "motorcycle intercom",

    "bike cleaning kit"
]

queries = set()

allOf = [
    phones,
    laptops,
    earbuds,
    watches,
    tvs,
    cameras,
    mice,
    keyboards,
    speakers,
    chargers,
    powerbanks,
    monitors,
    storage,
    phone_accessories,
    fridges,
    washing_machines,
    acs,
    microwaves,
    dishwashers,
    furniture,
    kitchen_appliances,
    fitness_equipment,
    automotive_accessories,
    pet_supplies,
    beauty_personal_care,
    motorcycle_accessories
]
for category in allOf:
    for product in category:
        queries.add(product)

color_categories = [
    phones,
    watches,
    phone_accessories,
    fridges,
    washing_machines,
    kitchen_appliances,
    fitness_equipment,
    motorcycle_accessories
]

for category in color_categories:
    for product in category:
        for color in colors:
            queries.add(f"{color} {product}")
            queries.add(f"best {color} {product}")
            queries.add(f"{color} {product} review")

size_categories = [
    fridges,
    acs,
    microwaves,
    dishwashers,
    washing_machines,
    tvs,
    kitchen_appliances,
    furniture,
    fitness_equipment,
    automotive_accessories,
    motorcycle_accessories,
    beauty_personal_care,
    pet_supplies
]

for category in size_categories:
    for product in category:
        for size in sizes:
            queries.add(f"{size} {product}")

all_categories = [
    phones,
    laptops,
    earbuds,
    tvs,
    cameras,
    watches,
    phone_accessories,
    fridges,
    washing_machines,
    acs,
    microwaves,
    dishwashers,
    mice,
    keyboards,
    speakers,
    chargers,
    powerbanks,
    monitors,
    storage,
    furniture,
    kitchen_appliances,
    fitness_equipment,
    automotive_accessories
]
for category in all_categories:
    for product in category:
        for template in templates:
            queries.add(template.format(product))


import random
from datetime import datetime, timedelta

rows = []

for query in queries:

    count = random.randint(100, 100000)

    timestamp = (
        datetime.now()
        - timedelta(days=random.randint(0, 365))
    ).strftime("%Y-%m-%d %H:%M:%S")

    rows.append({
        "query": query,
        "count": count,
        "timestamp": timestamp
    })

import pandas as pd

df = pd.DataFrame(rows)


df.to_csv(
    "search_queries_dataset.csv",
    index=False
)

print("CSV generated successfully!")
print("Total Queries:", len(queries))
# Out:
# CSV generated successfully!
# Total Queries: 40625

# %%
df.head(50)
# Out:
#                                           query  count            timestamp
# 0                           macbook pro m3 2026  11057  2025-08-22 19:47:30
# 1               samsung galaxy watch 6 for home  68542  2025-06-29 19:47:30
# 2                       corsair k55 under 10000  48180  2025-09-01 19:47:30
# 3            philips food processor under 50000  12044  2026-06-03 19:47:30
# 4    best gold samsung top load washing machine  31876  2026-03-20 19:47:30
# 5                     jump starter latest model  98235  2025-10-12 19:47:30
# 6                     car amplifier maintenance   7852  2026-05-04 19:47:30
# 7                    storage shelf under 100000  39242  2026-05-18 19:47:30
# 8                    philips toaster for office  85197  2025-06-23 19:47:30
# 9             butterfly electric kettle on sale  25515  2026-03-18 19:47:30
# 10                        cheap amazon echo dot  13779  2026-05-21 19:47:30
# ...

# %%
df.tail(50)
# Out:
#                                                  query  count  \
# 40575                      best green adjustable bench  45841
# 40576                          silver motorola edge 40  92135
# 40577               top rated godrej 244l refrigerator   2532
# 40578  haier top load washing machine with accessories  74181
# 40579                       new portable tyre inflator  97472
# 40580                       asus rog strix replacement  68911
# 40581                                sony a6700 review  59056
# 40582                              cheap recliner sofa  33762
# 40583                              premium study table  92468
# 40584                       car interior lights online  15761
# 40585                               steel dustbin 2023  19731
# 40586                     price of esr magsafe charger  37189
# 40587                         recliner sofa under 5000  73407
# 40588                          car perfume under 10000  99343
# ...
